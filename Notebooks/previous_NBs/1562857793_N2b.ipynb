# %% [markdown]
# Creates the final signal catalog from the signal list, satellite list and satbeam file.

# %% [markdown]
# ## 1. Initialization

# %% [markdown]
# Imports and necessary parameters.

# %%
## ----- IPYTHON COMMANDS ----- ##
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## ----- IMPORTS ----- ##
import sys
sys.path.insert(0, "./initialization/")
from imports import *
import parameters as pm
import time
import satellite_RFI.src.tle_mapping as tle

# %%
## ----- PARAMETERS ----- ##
path_beam = "{}satbeams_{}_{}_{}-{}.pkl".format(pm.folder, pm.block, pm.beam_model, *pm.freq_range)
path_knumbers = "knumbers.csv"
path_catalog = pm.folder + f"catalog_{pm.block}.csv"

# %% [markdown]
# ## 2. Creating the new beams file

# %% [markdown]
# The satbeam file is now corrected and doesn't need to be formatted differently, so we are just checking if the plots are close enough between the old and new versions.

# %%
# getting it
start = time.perf_counter()
data = pickle.load(open(path_beam,"rb",))
elapsed = time.perf_counter() - start
print(f"This took {elapsed:.2f} seconds, or {elapsed/60:.2f} minutes".format())

# getting satellite information
satellites = pd.read_csv(pm.folder + "satellites.csv")
satellites.set_index("NORAD ID",inplace=True)
# Out:
# This took 6.75 seconds, or 0.11 minutes

# %%
# cutting in the frequency range
idx_start = np.where(pm.frequency > pm.freq_range[0])[0][0] - 1
idx_end = np.where(pm.frequency > pm.freq_range[1])[0][0] + 1
fs = pm.frequency[idx_start:idx_end]
ts = pm.nd_s0

# showing axis
print("Frequency length:",len(fs))
print("Time length:",len(ts))
print(np.shape(data[list(data.keys())[0]]))
# Out:
# Frequency length: 2394
# Time length: 2241
# (2393, 2241)

# %%
# plotting satbeam maps
for i in data.keys():
    # Left: complete map
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    dplot = np.ma.masked_equal(data[i], 0)
    im = ax1.imshow(dplot, extent=[ts[0],ts[-1],fs[0],fs[-1]], 
                    origin="lower",aspect="auto")
    ax1.set_title(satellites.loc[i,f"Name {pm.block}"])
    ax1.set_xlabel("Time [s]")
    ax1.set_ylabel("Frequency [MHz]")
    fig.colorbar(im, ax=ax1)
        
    # Right: mean over frequency
    ax2.plot(ts-ts[0], np.ma.mean(dplot, axis=0))
    ax2.set_title("Mean over frequency")
    ax2.set_xlabel("Time")
    ax2.set_ylabel("Mean value")
    plt.tight_layout()
    plt.show()
    print()

# %% [markdown]
# ## 3. Creating the final signal list (specific to the particular observation)

# %% [markdown]
# #### A. Getting data

# %% [markdown]
# And now we create a signal catalog of all signals to fit in the data, where we use only the satellites that appear in the angular position maps.

# %%
# getting signal and satellite list
signals = pd.read_csv(pm.folder + "signals.csv")
satellites = pd.read_csv(pm.folder + "satellites.csv")
satellites.set_index("NORAD ID", inplace=True)

# %% [markdown]
# #### B. Creating new updated dataframe based on generation

# %% [markdown]
# We now create a signal list same as before, but now taking into account the specific generation that the satellite belongs to.

# %%
# creating necessary lists
data2 = []
IDrow = []

print("Selecting signals...")
for ID in data.keys():

    # selecting the generation and constellation
    gen = satellites.at[ID,"Generation"]
    cons = satellites.at[ID,"Constellation"]

    # parsing through the signals
    signals2 = signals[signals["Constellation"]==cons]
    for i in signals2.index:
        if gen in signals2.loc[i,"Generations"].split(","):
            data2.append(signals2.loc[i])
            IDrow.append(ID)
print("Done!")

# creating dataframe
data2 = pd.DataFrame(data2)
data2.insert(0, "NORAD ID", IDrow)
# Out:
# Selecting signals...
# Done!

# %% [markdown]
# #### C. Dealing with GLONASS k numbers

# %% [markdown]
# The k numbers make it so that the central frequencies in L1:L1OF(C/A), L1:L1SF(P), L2:L2OF(C/A) and L2:L2SF(P) are now $f_{L1}=1602.0+0.5625~k\text{ MHz}$ and $f_{L2}=1246.0+0.4375~k\text{ MHz}$.

# %%
# getting k numbers
ks = pd.read_csv(pm.folder + path_knumbers)
ks = ks.set_index("NORAD ID")

# %%
# parsing through GLONASS satellites
print("Substituting correct frequencies...")
for ID in data.keys():
    if satellites.at[ID,"Constellation"]=="GLONASS":
        # getting quantities
        k = ks.at[ID,f"k_{pm.block}"]
        mask1 = data2["NORAD ID"]==ID
        
        # substituting values
        data2.loc[mask1 & (data2["Signal"]=="L1:L1OF(C/A)"), "Frequency(MHz)"] = 1602.0 + k*0.5625
        data2.loc[mask1 & (data2["Signal"]=="L1:L1SF(P)"), "Frequency(MHz)"] = 1602.0 + k*0.5625
        data2.loc[mask1 & (data2["Signal"]=="L2:L2OF(C/A)"), "Frequency(MHz)"] = 1246.0 + k*0.4375
        data2.loc[mask1 & (data2["Signal"]=="L2:L2SF(P)"), "Frequency(MHz)"] = 1246.0 + k*0.4375
print("Done!")
# Out:
# Substituting correct frequencies...
# Done!

# %%
display(data2[data2["Constellation"]=="GLONASS"])
# Out:
#     NORAD ID Constellation Generations        Signal  Frequency(MHz)  \
# 8      29671       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1598.0625
# 9      29671       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1598.0625
# 10     29671       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1242.9375
# 11     29671       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1242.9375
# 8      32276       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1603.1250
# 9      32276       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1603.1250
# 10     32276       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1246.8750
# 11     32276       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1246.8750
# 8      36111       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1602.5625
# 9      36111       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1602.5625
# 10     36111       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1246.4375
# 11     36111       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1246.4375
# 8      36400       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1600.3125
# 9      36400       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1600.3125
# 10     36400       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1244.6875
# 11     36400       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1244.6875
# 8      37868       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1604.8125
# 9      37868       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1604.8125
# 10     37868       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1248.1875
# 11     37868       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1248.1875
# 8      37869       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1605.3750
# 9      37869       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1605.3750
# 10     37869       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1248.6250
# 11     37869       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1248.6250
# 8      39155       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1599.7500
# 9      39155       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1599.7500
# 10     39155       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1244.2500
# 11     39155       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1244.2500
# 8      40001       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1604.2500
# 9      40001       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1604.2500
# 10     40001       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1247.7500
# 11     40001       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1247.7500
# 12     40001       GLONASS    M+,K1,K2       L3:L3OC       1202.0250
# 8      41554       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1602.0000
# 9      41554       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1602.0000
# 10     41554       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1246.0000
# 11     41554       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1246.0000
# 12     41554       GLONASS    M+,K1,K2       L3:L3OC       1202.0250
# 8      44299       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1601.4375
# 9      44299       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1601.4375
# 10     44299       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1245.5625
# 11     44299       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1245.5625
# 12     44299       GLONASS    M+,K1,K2       L3:L3OC       1202.0250
# 8      37372       GLONASS  M,M+,K1,K2  L1:L1OF(C/A)       1598.6250
# 9      37372       GLONASS  M,M+,K1,K2    L1:L1SF(P)       1598.6250
# 10     37372       GLONASS  M,M+,K1,K2  L2:L2OF(C/A)       1243.3750
# 11     37372       GLONASS  M,M+,K1,K2    L2:L2SF(P)       1243.3750
# 12     37372       GLONASS    M+,K1,K2       L3:L3OC       1202.0250
#
#     Rate(MHz) Modulation  P(dBW)  G(dBi)
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 12    10.2300   BPSK(10)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 12    10.2300   BPSK(10)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 12    10.2300   BPSK(10)    10.0    10.0
# 8      0.5115  BPSK(0.5)    10.0    10.0
# 9      5.1150    BPSK(5)    10.0    10.0
# 10     0.5115  BPSK(0.5)    10.0    10.0
# 11     5.1150    BPSK(5)    10.0    10.0
# 12    10.2300   BPSK(10)    10.0    10.0

# %% [markdown]
# #### D. Rewriting data

# %% [markdown]
# Name will depend on the observation because this is tailored specifically to the observation that we are fitting (only satellites in here are the ones appearing in the beam maps); in order to fit other data, this process needs to be repeated (but the signal and satellite files all can be used at will).
#
# Information on constellation and generation is alreeady presented in the satellites file, and they are only useful for later interpretation of the data; likewise, the rate is already encoded in the modulation. As such, these columns are removed from the final signal list.

# %%
# dropping unnecessary columns
data2 = data2.drop(columns=["Constellation","Generations","Rate(MHz)"])

# %%
# saving the final signal list
data2.to_csv(path_catalog, index=False)
