# %%
import pandas as pd

# %%
excel_name = 'table3B_satellite_v3-1.csv'
df3 = pd.read_csv(excel_name)

# %%
df3.head(14)
# Out:
#     Sys Band   Signal  Frequency[MHz]       Modulation  Rate(MHz)  P_t (dBW)  \
# 0   GPS   L1     P(Y)         1575.42         BPSK(10)    10.2300       13.5
# 1   GPS   L1      C/A         1575.42          BPSK(1)     1.0230       16.5
# 2   GPS   L1    L1C-D         1575.42  TMBOC(6,1,4/33)     1.0230       10.0
# 3   GPS   L1    L1C-P         1575.42  TMBOC(6,1,4/33)     1.0230       10.0
# 4   GPS   L1      M-D         1575.42        BOC(10,5)     5.1150       18.2
# 5   GPS   L1      M-P         1575.42        BOC(10,5)     5.1150       18.2
# 6   GPS   L2     P(Y)         1227.60         BPSK(10)    10.2300       10.0
# 7   GPS   L2     L2CM         1227.60          BPSK(1)     0.5115       10.0
# 8   GPS   L2     L2CL         1227.60          BPSK(1)     0.5115       10.0
# 9   GPS   L2      M-D         1227.60        BOC(10,5)     5.1150       16.0
# 10  GPS   L2      M-P         1227.60        BOC(10,5)     5.1150       16.0
# 11  GPS   L5      L5I         1176.45         BPSK(10)    10.2300       18.0
# 12  GPS   L5      L5Q         1176.45         BPSK(10)    10.2300       18.0
# 13  GLO   L1  L1SF(P)         1602.00          BPSK(5)     5.1100        0.0
#
#     G_t (dBi)  Alpha
# 0        13.5    1.5
# 1        13.5    1.5
# 2        10.0    1.5
# 3        10.0    1.5
# 4        13.5    1.5
# 5        13.5    1.5
# 6        10.0    1.5
# 7        10.0    1.5
# 8        10.0    1.5
# 9        13.5    1.5
# 10       13.5    1.5
# 11       18.0    1.0
# 12       18.0    1.0
# 13        0.0    0.6

# %%
# Incase you need to remove indexes {nan only}

# df3 = df3.drop(71)

# %%
fs, fe = 1220, 1240

# data_n = df3[df3['Frequency[MHz]'] < fe]
# data_n = data_n[data_n['Frequency[MHz]'] > fs]
# data_n.sort_values(by='Frequency[MHz]', ascending=True)
# data_n

# %%
# # Searching for satellite by name

# sat = 'SBAS'

# sat_type = df3[df3['Sys'].str.contains(sat)]
# sat_type
# # sat_type.sort_values(by='Index', ascending=True)

# %%
# Index for which satellite to obtain

# idx = [7,8]
# idx = [20]

idx = [x for x in range(11, 13, 1)]

# %%
idx
# Out:
# [11, 12]

# %%
# # Power or gain
x = 1


for i in idx:
    df3.loc[i, 'Alpha'] = x




# # Change the frequency values

# for i in idx:
#     df3.loc[i, 'Frequency[MHz]'] = 1248.3

# %%
# df3[df3['Sys'].str.contains(sat)]

# data_n = df3[df3['Frequency[MHz]'] < fe]
# data_n = data_n[data_n['Frequency[MHz]'] > fs]
# data_n.sort_values(by='Frequency[MHz]', ascending=True)

# %%
df3.to_csv(path_or_buf=excel_name, index=None)

# %%
df3.head(15)
# Out:
#     Sys Band     Signal  Frequency[MHz]       Modulation  Rate(MHz)  \
# 0   GPS   L1       P(Y)         1575.42         BPSK(10)    10.2300
# 1   GPS   L1        C/A         1575.42          BPSK(1)     1.0230
# 2   GPS   L1      L1C-D         1575.42  TMBOC(6,1,4/33)     1.0230
# 3   GPS   L1      L1C-P         1575.42  TMBOC(6,1,4/33)     1.0230
# 4   GPS   L1        M-D         1575.42        BOC(10,5)     5.1150
# 5   GPS   L1        M-P         1575.42        BOC(10,5)     5.1150
# 6   GPS   L2       P(Y)         1227.60         BPSK(10)    10.2300
# 7   GPS   L2       L2CM         1227.60          BPSK(1)     0.5115
# 8   GPS   L2       L2CL         1227.60          BPSK(1)     0.5115
# 9   GPS   L2        M-D         1227.60        BOC(10,5)     5.1150
# 10  GPS   L2        M-P         1227.60        BOC(10,5)     5.1150
# 11  GPS   L5        L5I         1176.45         BPSK(10)    10.2300
# 12  GPS   L5        L5Q         1176.45         BPSK(10)    10.2300
# 13  GLO   L1    L1SF(P)         1602.00          BPSK(5)     5.1100
# 14  GLO   L1  L1OF(C/A)         1602.00        BPSK(0.5)     0.5110
#
#     P_t (dBW)  G_t (dBi)  Alpha
# 0        13.5       13.5    1.5
# 1        16.5       13.5    1.5
# 2        10.0       10.0    1.5
# 3        10.0       10.0    1.5
# 4        18.2       13.5    1.5
# 5        18.2       13.5    1.5
# 6        10.0       10.0    1.5
# 7        10.0       10.0    1.5
# 8        10.0       10.0    1.5
# 9        16.0       13.5    1.5
# 10       16.0       13.5    1.5
# 11       18.0       18.0    1.0
# 12       18.0       18.0    1.0
# 13        0.0        0.0    0.6
# 14        0.0        0.0    0.6

# %% [markdown]
# ### ------------------------------ END -----------------------------------------

# %%
# print df3.sort_values(by='Frequency[MHz]', ascending=True).to_latex(index=False)

# # print df3.to_latex(index=False)

# %%
import pickle
import numpy as np

# %% [markdown]
# Going to make a panda data frame for the csv file

# %%
df = df3.rename(columns={'P_txG_t(dB)': 'Alpha'})

# %%
df.shape[0]

# %%
idx = np.arange(df.shape[0])
for i in idx:
    df.loc[i, 'Alpha'] = 1

# %%
df.to_pickle('table3B_satellite_v3.p')

# %%
pickle.load(open('table3B_satellite_v3.p', 'rb'), encoding='latin1')
