# %% [markdown]
# ## Satellite Simulation Notebook
# - Author Brandon Engelbrecht

# %%
# %load_ext autoreload
# %autoreload 2

# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from satellite_RFI.src.satellite_sims import satellite_sim as ss
import time

# %%
s_time = time.time()


x1 = ss(file_name='1551055211', sats_only=None, sat_cataloque_name='table3B_satellite_v4_edits.csv')
x1.excecute(obs_time_start=2100, obs_time_end=2200, obs_frequency_start=800, obs_frequency_end=1400, 
            file_bias_choice=[0,0,1,0,0,0,0], add_sub=[None, None])


print time.time() - s_time
# Out:
# Time between: 2102.193146467209 and 2202.150858640671 in seconds
#
# Frequency between: 981.4 and 1400.2 in MHz
#
# Bias choice is follows:gps-ops, glo-ops, galileo, beidou, irnss, sbas, noise
# 6.109197855

# %%
x1.plotting(individual=None, logger=None, tod_limit=None, save_file=None)
