# %%
from satellite_RFI.src.tools import tle_download, sat_extract, rewrite_sat_cat

# %%
path_store = 'TLE/'

# %%
## Downloads the file contents of the navigational and geostaionary satellites
tle_download(direc_path=path_store)
# Out:
# Path alredy exists: TLE/2023_02_09_tle/
# Two Line Element location: TLE/2023_02_09_tle/
# 'TLE/2023_02_09_tle/'

# %%
# Extracts the IRNSS and QZS from the geo satellites
sat_extract(folder=path_store+'2023_02_09_tle/')

# %%
# rewrites the contents of the files to remove spaces in the name designators of the satellite
rewrite_sat_cat(file_path='TLE/2023_02_09_tle/geo.txt')
