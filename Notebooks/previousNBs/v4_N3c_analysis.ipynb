# %% [markdown]
# **VERSION v4**: I changed some stuff in the code (explained below) and used the new signal catalog, and results came out very weird. In order to understand, I performed the changes to the code using the old signal catalog and found that now it gives the same results (could have been a bug or an actual problem with the catalog).

# %% [markdown]
# ## 1. Initialization

# %% [markdown]
# Imports and general parameters (from *parameters.py*).

# %%
## ----- IPYTHON COMMANDS ----- ##
# %load_ext autoreload
# %autoreload 2

# %%
## ----- IMPORTS ----- ##
import satellite_RFI.src.simulation as sim
import natsort
import sys
sys.path.insert(0, './initialization/')
from imports import *
import parameters as pm
from matplotlib.ticker import LogLocator, FormatStrFormatter

# %%
## ----- FITTING PARAMETERS ----- ##

# folder and name of final results file
folder = "results/v4_results/"

# cost function from eq. 11 (options: "C1"=radiometer, "C2"=1)
CF = "C1"

# angular mask [degrees] (options: "1F","5F" or None)
deg = None
if deg==None:  path_nearby = None
else:  path_nearby = (pm.path_data+"nearby_satellites/nearby_satellite_close_angle_"+deg+".p")

# thermal mask [kelvin] (options: 25,50,100 or None)
temp = None

# threshold pixel mask (options: 2,5,7 or None)
pix = None

# temporal mask [seconds] (options: 775-1000, 2200-2400, 5500-6200 or None)
time_slice = (None,None)

# %%
pm.show_parameters(CF, deg, temp, pix, time_slice)
print("")
print(f"Showing results from folder: {folder}")
# Out:
# Block: 1551055211
# Frequency range: 1100 - 1350 MHz
# Time range: inf - inf seconds
# The cost function denominator will be: radiometer equation (C1).
# Masking: None
#
# Showing results from folder: results/v4_results/

# %% [markdown]
# ## 2. Set-up of global variables and functions

# %% [markdown]
# We start by initializing the simulation, and also the satellite listing that has additional information (such as the constellation, generation and name of a given satellite).

# %%
# initializing the simulation
sat = sim.SatelliteSimulation(
    survey_info=[pm.nd_s0, pm.frequency],
    path_catalog="Satellite_Catalogue/individual_satellite_constellation_catalog.csv",
    path_beam="1551055211_satellite_angular_positions_emss_1000-1500.npz",
    freq_range=pm.freq_range,
    freq_slice=pm.freq_slice,
    time_slice=time_slice,
    verbose=True,
)

# getting observations and mask
sat.use_observations(path_observations=pm.path_observations, verbose=True)
sat.use_mask(path_nearby, temp, pix, verbose=True)

# define some quantities
frequency = sat.frequency[sat.ifreq[0]:sat.ifreq[1]]
time = sat.time[sat.itime[0]:sat.itime[1]]
# Out:
# Getting catalog...
#  - Number of signals in satellite catalog: 435 (initial), 286 (final).
# Getting beam response...
#  - Number of satellites present: 73
#  - Size of sat_beam: 1.437 GB
# Getting temperature factors for each signal...
#  - Length of Tb_factors: 286
#  - Size of Tb_factors: 0.003 GB
# Starting index of satellites:  [  0   4   8  12  16  20  24  28  32  36  40  44  48  52  56  60  64  68
#   72  76  80  84  88  92  96 100 104 108 112 114 116 118 120 122 123 124
#  125 126 127 128 129 130 131 136 141 146 151 156 161 166 171 176 181 186
#  191 196 201 206 211 216 221 226 231 236 241 246 251 256 261 266 271 276
#  281]
# Getting observational data...
#  - Size of observational data: 0.020 GB
#  - Shape of observational data: (1199, 2204)
# Size of arrays:
#  - Frequency:  (1199,)
#  - Time:  (2204,)
#  - Size of simulated Tb_factors:  (286, 1199)
#  - Size of simulated sat_beam:  (73, 1199, 2204)
#  - Size of observations:  (1199, 2204)

# %%
# getting alpha best-fit values
print("Getting best-fit values...")
fname = pm.my_name(folder, CF, deg, temp, pix, time_slice)
alphas = pickle.load( open(fname,"rb") )["best-fit"]

# getting the simulation
print("Simulating...")
sat.simulate(alphas)
# Out:
# Getting best-fit values...
# Simulating...

# %%
# getting satellite info
satellites = pd.read_csv("data/satellites.csv")
satellites = satellites.set_index("Brandon Name")

# getting signal info
#signals = pd.read_csv("data/signals.csv")
#signals = signals[signals["Frequency(MHz)"] >= pm.freq_slice[0]]
#signals = signals[signals["Frequency(MHz)"] <= pm.freq_slice[1]]

# %% [markdown]
# ## 3. Graphs

# %% [markdown]
# We now define several different graphs that will check different properties of the best-fit simulation that was obtained. The first functions plot the alphas obtained for each constellation (as a function of the signal, where each satellite has a curve), and also the total power (with contributions from P and G) which will represent the true amplitude of the signal.

# %%
# ------------------ plot_alphas ------------------- #
def plot_alphas(con, log=False):
    ''' Plot alphas of each signal for a given constellation. '''

    # creating figure
    fig, ax = plt.subplots(figsize=(9, 5))
    linestyles = ["-", "--", "-.", ":"]
    nulls = []

    for i,name in enumerate(sat.sats):
        # getting values
        if satellites.loc[name,"Constellation"]!=con:  continue
        ys = alphas[sat.index_sats[i]: sat.index_sats[i]+sat.n_signals[i]]
        xs = sat.catalog.loc[sat.catalog["Sat"]==name,"Signal"]

        # if satellite has only null alphas, remove
        if np.abs(np.linalg.norm(ys))<1e-6:  
            nulls.append(name)
            continue

        #plotting the rest
        ys_plot = np.where(ys>0,ys,np.nan)
        if log:  ax.plot(xs, ys_plot, linestyle=linestyles[i%4], marker=".", label=name)
        else:  ax.plot(xs, ys_plot, linestyle=linestyles[i%4], marker=".", label=f"{name}")

        # plotting zero values
        idx0 = np.where(np.abs(ys)<1e-6)[0]
        if len(idx0):
            ax.plot(np.asarray(xs)[idx0], np.full(len(idx0), ax.get_ylim()[0]), "x",
                    color=ax.lines[-1].get_color(), ms=8)

    # showing figure
    if log:  
        ax.set_yscale("log")
        ax.yaxis.set_major_locator(LogLocator(base=10, subs=(1, 2, 5)))
        ax.yaxis.set_major_formatter(FormatStrFormatter("%g"))
    ax.set_ylabel('Amplitude')
    ax.set_xlabel(r'Signal $[\alpha_{i}]$')
    ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0)
    ax.set_title(f"Alphas for {con}")
    fig.tight_layout()
    plt.show()
    print(f"Satellites with only null alphas: {nulls}")

# %%
cons = ["GPS","GLONASS","GALILEO","BEIDOU","SBAS","IRNSS"]
for con in cons:
    plot_alphas(con,log=False)
# Out:
# Satellites with only null alphas: ['GPS-BIIF-8(PRN-03)', 'GPS-BIIR-6(PRN-14)', 'GPS-BIIRM-2-(PRN-31)', 'GPS-BIIR-10-(PRN-22)']
# Satellites with only null alphas: ['COSMOS-2464-(736)', 'COSMOS-2433-(720)', 'COSMOS-2456-(730)']
# Satellites with only null alphas: ['GSAT0201-(PRN-E18)', 'GSAT0205-(PRN-E24)', 'GSAT0210-(PRN-E01)', 'GSAT0222-(PRN-E33)', 'GSAT0213-(PRN-E04)', 'GSAT0214-(PRN-E05)', 'GSAT0102-(PRN-E12)', 'GSAT0212-(PRN-E03)', 'GSAT0101-(PRN-E11)']
# Satellites with only null alphas: ['BEIDOU-I1-S', 'BEIDOU-IGSO-5', 'BEIDOU-I2-S', 'BEIDOU-M6', 'BEIDOU-IGSO-3', 'BEIDOU-M4', 'BEIDOU-3-M17', 'BEIDOU-3-M5', 'BEIDOU-3-M1', 'BEIDOU-G6', 'BEIDOU-G3', 'BEIDOU-3-M8']
# Satellites with only null alphas: ['AOR-E-(EGNOS/PRN-120)', 'ASTRA-5B-(EGNOS/PRN-123)', 'GSAT-15-(GAGAN/PRN-139)-', 'LUCH-5V-(SDCM/PRN-141)', 'IOR-W-(EGNOS/PRN-126)', 'SES-5-(EGNOS/PRN-136)', 'GSAT-10-(GAGAN/PRN-128)-']
# Satellites with only null alphas: ['IRNSS-1B', 'IRNSS-1I']

# %%
# ------------------ plot_power ------------------- #
def plot_power(con, log=False):
    ''' Plot alphas of each signal for a given constellation. '''

    # creating figure
    fig, ax = plt.subplots(figsize=(9, 5))
    linestyles = ["-", "--", "-.", ":"]
    nulls = []

    for i,name in enumerate(sat.sats):
        # getting values
        if satellites.loc[name,"Constellation"]!=con:  continue
        Ps = np.array(sat.catalog["P_t (dBW)"])[sat.index_sats[i]: sat.index_sats[i]+sat.n_signals[i]]
        Gs = np.array(sat.catalog["G_t (dBi)"])[sat.index_sats[i]: sat.index_sats[i]+sat.n_signals[i]]
        ys = alphas[sat.index_sats[i]: sat.index_sats[i]+sat.n_signals[i]] * 10**(Ps/10 + Gs/10)
        xs = sat.catalog.loc[sat.catalog["Sat"]==name,"Signal"]

        # if satellite has only null alphas, remove
        if np.abs(np.linalg.norm(ys))<1e-6:  
            nulls.append(name)
            continue

        #plotting the rest
        ys_plot = np.where(ys>0,ys,np.nan)
        if log:  ax.plot(xs, ys_plot, linestyle=linestyles[i%4], marker=".", label=name)
        else:  ax.plot(xs, ys_plot, linestyle=linestyles[i%4], marker=".", label=f"{name}")

        # plotting zero values
        idx0 = np.where(np.abs(ys)<1e-6)[0]
        if len(idx0):
            ax.plot(np.asarray(xs)[idx0], np.full(len(idx0), ax.get_ylim()[0]), "x",
                    color=ax.lines[-1].get_color(), ms=8)

    # showing figure
    if log:  
        ax.set_yscale("log")
        ax.yaxis.set_major_locator(LogLocator(base=10, subs=(1, 2, 5)))
        ax.yaxis.set_major_formatter(FormatStrFormatter("%g"))
    ax.set_ylabel(r'Power $[\alpha_{i} \times 10^{P/10 + G/10}]$')
    ax.set_xlabel(r'Signal $[\alpha_{i}]$')
    ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1), borderaxespad=0)
    ax.set_title(f"Power for {con}")
    fig.tight_layout()
    plt.show()
    print(f"Satellites with only null alphas: {nulls}")

# %%
cons = ["GPS","GLONASS","GALILEO","BEIDOU","SBAS","IRNSS"]
for con in cons:
    plot_power(con,log=False)
# Out:
# Satellites with only null alphas: ['GPS-BIIF-8(PRN-03)', 'GPS-BIIR-6(PRN-14)', 'GPS-BIIRM-2-(PRN-31)', 'GPS-BIIR-10-(PRN-22)']
# Satellites with only null alphas: ['COSMOS-2464-(736)', 'COSMOS-2433-(720)', 'COSMOS-2456-(730)']
# Satellites with only null alphas: ['GSAT0201-(PRN-E18)', 'GSAT0205-(PRN-E24)', 'GSAT0210-(PRN-E01)', 'GSAT0222-(PRN-E33)', 'GSAT0213-(PRN-E04)', 'GSAT0214-(PRN-E05)', 'GSAT0102-(PRN-E12)', 'GSAT0212-(PRN-E03)', 'GSAT0101-(PRN-E11)']
# Satellites with only null alphas: ['BEIDOU-I1-S', 'BEIDOU-IGSO-5', 'BEIDOU-I2-S', 'BEIDOU-M6', 'BEIDOU-IGSO-3', 'BEIDOU-M4', 'BEIDOU-3-M17', 'BEIDOU-3-M5', 'BEIDOU-3-M1', 'BEIDOU-G6', 'BEIDOU-G3', 'BEIDOU-3-M8']
# Satellites with only null alphas: ['AOR-E-(EGNOS/PRN-120)', 'ASTRA-5B-(EGNOS/PRN-123)', 'GSAT-15-(GAGAN/PRN-139)-', 'LUCH-5V-(SDCM/PRN-141)', 'IOR-W-(EGNOS/PRN-126)', 'SES-5-(EGNOS/PRN-136)', 'GSAT-10-(GAGAN/PRN-128)-']
# Satellites with only null alphas: ['IRNSS-1B', 'IRNSS-1I']

# %%
# --------------------- plot_1d -------------------- #
def plot_1d(con, axis="frequency"):
    ''' Plot 1d and 2d maps of the contribution of each satellite. '''

    # satellites with null alphas get removed
    nulls = []

    for i,name in enumerate(sat.sats):
        # if alphas are null or satellite is not in cons, remove
        ind_i = sat.index_sats[i]
        ind_e = sat.n_signals[i]
        if satellites.loc[name,"Constellation"]!=con:  continue
        if np.abs(np.linalg.norm(alphas[ind_i : ind_i+ind_e]))<1e-6:  
            nulls.append(satellites.loc[name,"Satellite"])
            continue

        # calculating contribution
        sim_i = np.zeros_like(sat.obs)
        for j in range(ind_i, ind_i+ind_e):
            sim_i += sat.sat_beam[i] * sat.Tb_factors[j][:,None] * alphas[j]
        
        # plotting figure
        fig, axs = plt.subplots(figsize=(20, 4), ncols=2, nrows=1, sharex=True, sharey=False)
        for ax in axs: 
            if axis=="frequency":
                ax.plot(frequency, np.ma.mean(sat.obs_BGsub.T, axis=0), label='Observation')
                ax.plot(frequency, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=0), 
                        '--', label='Simulation')
                ax.set_xlabel('Frequency [MHz]')
            elif axis=="time": 
                ax.plot(time, np.ma.mean(sat.obs_BGsub.T, axis=1), label='Observation')
                ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1), 
                        '--', label='Simulation')
                ax.set_xlabel('Time [s]')
            ax.set_ylabel('Temperature [K]')
            ax.legend(loc="upper left")
        axs[1].set_yscale("log")
        fig.suptitle(f"Satellite {satellites.loc[name,'Satellite']}")
        fig.tight_layout()
        plt.show()
        
    print(f"Satellites with only null alphas: {nulls}")

# %%
for con in cons:
    plot_1d(con, axis="frequency")
# Out:
# Satellites with only null alphas: ['GPS-BIIF-8', 'GPS-BIIR-6', 'GPS-BIIRM-2', 'GPS-BIIR-10']
# <ipython-input-22-dcaeaa92f70b>:27: RuntimeWarning: Mean of empty slice
#   ax.plot(frequency, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=0),
# <ipython-input-22-dcaeaa92f70b>:27: RuntimeWarning: Mean of empty slice
#   ax.plot(frequency, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=0),
# Satellites with only null alphas: ['COSMOS 2464', 'COSMOS 2433', 'COSMOS 2456']
# Satellites with only null alphas: ['GSAT0201', 'GSAT0205', 'GSAT0210', 'GSAT0222', 'GSAT0213', 'GSAT0214', 'GSAT0102', 'GSAT0212', 'GSAT0101']
# Satellites with only null alphas: ['BEIDOU-3S IGSO-1S', 'BEIDOU-2 IGSO-5', 'BEIDOU-3S IGSO-2S', 'BEIDOU-2 M6', 'BEIDOU-2 IGSO-3', 'BEIDOU-2 M4', 'BEIDOU-3 M17', 'BEIDOU-3 M5', 'BEIDOU-3 M1', 'BEIDOU-2 G6', 'BEIDOU-2 G3', 'BEIDOU-3 M8']
# Satellites with only null alphas: ['EGNOS: Inmarsat-3 F2', 'EGNOS: Astra 5B', 'GAGAN: GSAT-15', 'SDCM: Luch-5V', 'EGNOS: Inmarsat-4 F2', 'EGNOS: SES-5', 'GAGAN: GSAT-10']
# Satellites with only null alphas: ['IRNSS-1B', 'IRNSS-1I']

# %%
for con in cons:
    plot_1d(con, axis="time")
# Out:
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# Satellites with only null alphas: ['GPS-BIIF-8', 'GPS-BIIR-6', 'GPS-BIIRM-2', 'GPS-BIIR-10']
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# Satellites with only null alphas: ['COSMOS 2464', 'COSMOS 2433', 'COSMOS 2456']
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# <ipython-input-22-dcaeaa92f70b>:32: RuntimeWarning: Mean of empty slice
#   ax.plot(time, np.nanmean(np.where(sim_i.T>0,sim_i.T,np.nan), axis=1),
# Satellites with only null alphas: ['GSAT0201', 'GSAT0205', 'GSAT0210', 'GSAT0222', 'GSAT0213', 'GSAT0214', 'GSAT0102', 'GSAT0212', 'GSAT0101']
# Satellites with only null alphas: ['BEIDOU-3S IGSO-1S', 'BEIDOU-2 IGSO-5', 'BEIDOU-3S IGSO-2S', 'BEIDOU-2 M6', 'BEIDOU-2 IGSO-3', 'BEIDOU-2 M4', 'BEIDOU-3 M17', 'BEIDOU-3 M5', 'BEIDOU-3 M1', 'BEIDOU-2 G6', 'BEIDOU-2 G3', 'BEIDOU-3 M8']
# Satellites with only null alphas: ['EGNOS: Inmarsat-3 F2', 'EGNOS: Astra 5B', 'GAGAN: GSAT-15', 'SDCM: Luch-5V', 'EGNOS: Inmarsat-4 F2', 'EGNOS: SES-5', 'GAGAN: GSAT-10']
# Satellites with only null alphas: ['IRNSS-1B', 'IRNSS-1I']
